# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder

# %%
nba_teams = teams.get_teams()

hawks = [team for team in nba_teams if team['abbreviation'] == 'ATL'][0]
hawks_id = hawks['id']

celtics = [team for team in nba_teams if team['abbreviation'] == 'BOS'][0]
celtics_id = celtics['id']

nets = [team for team in nba_teams if team['abbreviation'] == 'BKN'][0]
nets_id = nets['id']

hornets = [team for team in nba_teams if team['abbreviation'] == 'CHA'][0]
hornets_id = hornets['id']

bulls = [team for team in nba_teams if team['abbreviation'] == 'CHI'][0]
bulls_id = bulls['id']

cavs = [team for team in nba_teams if team['abbreviation'] == 'CLE'][0]
cavs_id = cavs['id']

mavs = [team for team in nba_teams if team['abbreviation'] == 'DAL'][0]
mavs_id = mavs['id']

nuggets = [team for team in nba_teams if team['abbreviation'] == 'DEN'][0]
nuggets_id = nuggets['id']

pistons = [team for team in nba_teams if team['abbreviation'] == 'DET'][0]
pistons_id = pistons['id']

warriors = [team for team in nba_teams if team['abbreviation'] == 'GSW'][0]
warriors_id = warriors['id']

rockets = [team for team in nba_teams if team['abbreviation'] == 'HOU'][0]
rockets_id = rockets['id']

pacers = [team for team in nba_teams if team['abbreviation'] == 'IND'][0]
pacers_id = pacers['id']

clippers = [team for team in nba_teams if team['abbreviation'] == 'LAC'][0]
clippers_id = clippers['id']

lakers = [team for team in nba_teams if team['abbreviation'] == 'LAL'][0]
lakers_id = lakers['id']

grizzlies = [team for team in nba_teams if team['abbreviation'] == 'MEM'][0]
grizzlies_id = grizzlies['id']

heat = [team for team in nba_teams if team['abbreviation'] == 'MIA'][0]
heat_id = heat['id']

bucks = [team for team in nba_teams if team['abbreviation'] == 'MIL'][0]
bucks_id = bucks['id']

twolves = [team for team in nba_teams if team['abbreviation'] == 'MIN'][0]
twolves_id = twolves['id']

pelicans = [team for team in nba_teams if team['abbreviation'] == 'NOP'][0]
pelicans_id = pelicans['id']

knicks = [team for team in nba_teams if team['abbreviation'] == 'NYK'][0]
knicks_id = knicks['id']

thunder = [team for team in nba_teams if team['abbreviation'] == 'OKC'][0]
thunder_id = thunder['id']

magic = [team for team in nba_teams if team['abbreviation'] == 'ORL'][0]
magic_id = magic['id']

sixers = [team for team in nba_teams if team['abbreviation'] == 'PHI'][0]
sixers_id = sixers['id']

suns = [team for team in nba_teams if team['abbreviation'] == 'PHX'][0]
suns_id = suns['id']

blazers = [team for team in nba_teams if team['abbreviation'] == 'POR'][0]
blazers_id = blazers['id']

kings = [team for team in nba_teams if team['abbreviation'] == 'SAC'][0]
kings_id = kings['id']

spurs = [team for team in nba_teams if team['abbreviation'] == 'SAS'][0]
spurs_id = spurs['id']

raptors = [team for team in nba_teams if team['abbreviation'] == 'TOR'][0]
raptors_id = raptors['id']

jazz = [team for team in nba_teams if team['abbreviation'] == 'UTA'][0]
jazz_id = jazz['id']

wizards = [team for team in nba_teams if team['abbreviation'] == 'WAS'][0]
wizards_id = wizards['id']

# %%
hawks_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=hawks_id)
celtics_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)
nets_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=nets_id)
hornets_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=hornets_id)
bulls_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=bulls_id)
cavs_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=cavs_id)
mavs_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=mavs_id)
nuggets_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=nuggets_id)
pistons_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=pistons_id)
warriors_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=warriors_id)
rockets_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=rockets_id)
pacers_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=pacers_id)
clippers_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=clippers_id)
lakers_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=lakers_id)
grizzlies_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=grizzlies_id)
heat_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=heat_id)
bucks_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=bucks_id)
twolves_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=twolves_id)
pelicans_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=pelicans_id)
knicks_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=knicks_id)
thunder_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=thunder_id)
magic_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=magic_id)
sixers_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=sixers_id)
suns_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=suns_id)
blazers_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=blazers_id)
kings_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=kings_id)
spurs_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=spurs_id)
raptors_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=raptors_id)
jazz_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=jazz_id)
wizards_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=wizards_id)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1343             try:
# ...

# %%
hawks_games = hawks_gamefinder.get_data_frames()[0]
hawks_games.head()

celtics_games = celtics_gamefinder.get_data_frames()[0]
celtics_games.head()

nets_games = nets_gamefinder.get_data_frames()[0]
nets_games.head()

hornets_games = hornets_gamefinder.get_data_frames()[0]
hornets_games.head()

bulls_games = bulls_gamefinder.get_data_frames()[0]
bulls_games.head()

cavs_games = cavs_gamefinder.get_data_frames()[0]
cavs_games.head()

mavs_games = mavs_gamefinder.get_data_frames()[0]
mavs_games.head()

nuggets_games = nuggets_gamefinder.get_data_frames()[0]
nuggets_games.head()

pistons_games = pistons_gamefinder.get_data_frames()[0]
pistons_games.head()

warriors_games = warriors_gamefinder.get_data_frames()[0]
warriors_games.head()

rockets_games = rockets_gamefinder.get_data_frames()[0]
rockets_games.head()

pacers_games = pacers_gamefinder.get_data_frames()[0]
pacers_games.head()

clippers_games = clippers_gamefinder.get_data_frames()[0]
clippers_games.head()

lakers_games = lakers_gamefinder.get_data_frames()[0]
lakers_games.head()

grizzlies_games = grizzlies_gamefinder.get_data_frames()[0]
grizzlies_games.head()

heat_games = heat_gamefinder.get_data_frames()[0]
heat_games.head()

bucks_games = bucks_gamefinder.get_data_frames()[0]
bucks_games.head()

twolves_games = twolves_gamefinder.get_data_frames()[0]
twolves_games.head()

pelicans_games = pelicans_gamefinder.get_data_frames()[0]
pelicans_games.head()

knicks_games = knicks_gamefinder.get_data_frames()[0]
knicks_games.head()

thunder_games = thunder_gamefinder.get_data_frames()[0]
thunder_games.head()

magic_games = magic_gamefinder.get_data_frames()[0]
magic_games.head()

sixers_games = sixers_gamefinder.get_data_frames()[0]
sixers_games.head()

suns_games = suns_gamefinder.get_data_frames()[0]
suns_games.head()

blazers_games = blazers_gamefinder.get_data_frames()[0]
blazers_games.head()

kings_games = kings_gamefinder.get_data_frames()[0]
kings_games.head()

spurs_games = spurs_gamefinder.get_data_frames()[0]
spurs_games.head()

raptors_games = raptors_gamefinder.get_data_frames()[0]
raptors_games.head()

jazz_games = jazz_gamefinder.get_data_frames()[0]
jazz_games.head()

wizards_games = wizards_gamefinder.get_data_frames()[0]
wizards_games.head()

# %%
last_hawks_game = hawks_games.sort_values('GAME_DATE').iloc[-1]
last_celtics_game = celtics_games.sort_values('GAME_DATE').iloc[-1]
last_nets_game = nets_games.sort_values('GAME_DATE').iloc[-1]
last_hornets_game = hornets_games.sort_values('GAME_DATE').iloc[-1]
last_bulls_game = bulls_games.sort_values('GAME_DATE').iloc[-1]
last_cavs_game = cavs_games.sort_values('GAME_DATE').iloc[-1]
last_mavs_game = mavs_games.sort_values('GAME_DATE').iloc[-1]
last_nuggets_game = nuggets_games.sort_values('GAME_DATE').iloc[-1]
last_pistons_game = pistons_games.sort_values('GAME_DATE').iloc[-1]
last_warriors_game = warriors_games.sort_values('GAME_DATE').iloc[-1]
last_rockets_game = rockets_games.sort_values('GAME_DATE').iloc[-1]
last_pacers_game = pacers_games.sort_values('GAME_DATE').iloc[-1]
last_clippers_games = clippers_games.sort_values('GAME_DATE').iloc[-1]
last_lakers_game = lakers_games.sort_values('GAME_DATE').iloc[-1]
last_grizzlies_game = grizzlies_games.sort_values('GAME_DATE').iloc[-1]
last_heat_game = heat_games.sort_values('GAME_DATE').iloc[-1]
last_bucks_game = bucks_games.sort_values('GAME_DATE').iloc[-1]
last_twolves_game = twolves_games.sort_values('GAME_DATE').iloc[-1]
last_pelicans_game = pelicans_games.sort_values('GAME_DATE').iloc[-1]
last_knicks_game = knicks_games.sort_values('GAME_DATE').iloc[-1]
last_thunder_game = thunder_games.sort_values('GAME_DATE').iloc[-1]
last_magic_game = magic_games.sort_values('GAME_DATE').iloc[-1]
last_sixers_game = sixers_games.sort_values('GAME_DATE').iloc[-1]
last_suns_game = suns_games.sort_values('GAME_DATE').iloc[-1]
last_blazers_game = blazers_games.sort_values('GAME_DATE').iloc[-1]
last_kings_game = kings_games.sort_values('GAME_DATE').iloc[-1]
last_spurs_game = spurs_games.sort_values('GAME_DATE').iloc[-1]
last_raptors_game = raptors_games.sort_values('GAME_DATE').iloc[-1]
last_jazz_game = jazz_games.sort_values('GAME_DATE').iloc[-1]
last_wizards_game = wizards_games.sort_values('GAME_DATE').iloc[-1]

# %%
last_cavs_game['WL']

# %%
last_cavs_game['PTS']

# %%
def who_won(pick, points):
    if pick == 'hawks' and last_hawks_game['WL'] == 'W' and int(points) == last_hawks_game['PTS']:
        return 'You Win!'
    elif pick == 'celtics' and last_celtics_game['WL'] == 'W' and int(points) == last_celtics_game['PTS']:
        return 'You Win!'
    elif pick == 'nets' and last_nets_game['WL'] == 'W' and int(points) == last_nets_game['PTS']:
        return 'You Win!'
    elif pick == 'hornets' and last_hornets_game['WL'] == 'W' and int(points) == last_hornets_game['PTS']:
        return 'You Win!'
    elif pick == 'bulls' and last_bulls_game['WL'] == 'W' and int(points) == last_bulls_game['PTS']:
        return 'You Win!'
    elif pick == 'cavs' and last_cavs_game['WL'] == 'W' and int(points) == last_cavs_game['PTS']:
        return 'You Win!'
    elif pick == 'mavs' and last_mavs_game['WL'] == 'W' and int(points) == last_mavs_game['PTS']:
        return 'You Win!'
    elif pick == 'nuggets' and last_nuggets_game['WL'] == 'W' and int(points) == last_nuggets_game['PTS']:
        return 'You Win!'
    elif pick == 'pistons' and last_pistons_game['WL'] == 'W' and int(points) == last_pistons_game['PTS']:
        return 'You Win!'
    elif pick == 'warriors' and last_warriors_game['WL'] == 'W' and int(points) == last_warriors_game['PTS']:
        return 'You Win!'
    elif pick == 'rockets' and last_rockets_game['WL'] == 'W' and int(points) == last_rockets_game['PTS']:
        return 'You Win!'
    elif pick == 'pacers' and last_pacers_game['WL'] == 'W' and int(points) == last_pacers_game['PTS']:
        return 'You Win!'
    elif pick == 'clippers' and last_clippers_game['WL'] == 'W' and int(points) == last_clippers_game['PTS']:
        return 'You Win!'
    elif pick == 'lakers' and last_lakers_game['WL'] == 'W' and int(points) == last_lakers_game['PTS']:
        return 'You Win!'
    elif pick == 'grizzlies' and last_grizzlies_game['WL'] == 'W' and int(points) == last_grizzlies_game['PTS']:
        return 'You Win!'
    elif pick == 'heat' and last_heat_game['WL'] == 'W' and int(points) == last_heat_game['PTS']:
        return 'You Win!'
    elif pick == 'bucks' and last_bucks_game['WL'] == 'W' and int(points) == last_bucks_game['PTS']:
        return 'You Win!'
    elif pick == 'twolves' and last_twolves_game['WL'] == 'W' and int(points) == last_twolves_game['PTS']:
        return 'You Win!'
    elif pick == 'pelcians' and last_pelicans_game['WL'] == 'W' and int(points) == last_pelicans_game['PTS']:
        return 'You Win!'
    elif pick == 'knicks' and last_knicks_game['WL'] == 'W' and int(points) == last_knicks_game['PTS']:
        return 'You Win!'
    elif pick == 'thunder' and last_thunder_game['WL'] == 'W' and int(points) == last_thunder_game['PTS']:
        return 'You Win!'
    elif pick == 'magic' and last_magic_game['WL'] == 'W' and int(points) == last_magic_game['PTS']:
        return 'You Win!'
    elif pick == 'sixers' and last_sixers_game['WL'] == 'W' and int(points) == last_sixers_game['PTS']:
        return 'You Win!'
    elif pick == 'suns' and last_suns_game['WL'] == 'W' and int(points) == last_suns_game['PTS']:
        return 'You Win!'
    elif pick == 'blazers' and last_blazers_game['WL'] == 'W' and int(points) == last_blazers_game['PTS']:
        return 'You Win!'
    elif pick == 'kings' and last_kings_game['WL'] == 'W' and int(points) == last_kings_game['PTS']:
        return 'You Win!'
    elif pick == 'spurs' and last_spurs_game['WL'] == 'W' and int(points) == last_spurs_game['PTS']:
        return 'You Win!'
    elif pick == 'raptors' and last_raptors_game['WL'] == 'W' and int(points) == last_raptors_game['PTS']:
        return 'You Win!'
    elif pick == 'jazz' and last_jazz_game['WL'] == 'W' and int(points) == last_jazz_game['PTS']:
        return 'You Win!'
    elif pick == 'wizards' and last_wizards_game['WL'] == 'W' and int(points) == last_wizard_game['PTS']:
        return 'You Win!'
    else:
        return 'You lost! Try again next time!'

# %%
user_team_pick = input("Tell us who will win: ")
user_game_score = input("Tell us what the winning team will score: ")

# %%
print (user_team_pick)

# %%
print (user_game_score)

# %%
who_won(user_team_pick, user_game_score)
